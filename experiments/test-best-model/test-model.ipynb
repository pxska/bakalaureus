# %%
import json
import time
import os
import re

from modules.preprocessing_protocols import preprocess_text
from modules.results_extraction import extract_results

from modules.corpus_readers_fixed import read_from_tsv
from estnltk import Text
from estnltk.taggers import NerTagger
from estnltk.taggers import WordLevelNerTagger
from estnltk.converters import text_to_json
from estnltk.converters import json_to_text
from estnltk.layer_operations import flatten

from estnltk.taggers import WordLevelNerTagger

# %%
def find(name, path):
    for root, dirs, files in os.walk(path):
        if name in files:
            return os.path.join(root, name)

# %%
def tag_files(testing_files_dir, model_dir, is_tsv = False):
    nertagger = NerTagger(model_dir)
    word_level_ner = WordLevelNerTagger(model_dir)
    removed_layers = ['sentences', 'morph_analysis', 'compound_tokens', 'ner', 'words', 'tokens']
    
    path = os.path.join(model_dir, 'vallakohtufailid-trained-nertagger')
    if not os.path.exists(path):
        os.mkdir(path)
    
    print("(!) Alustan failide märgendamist")
    if is_tsv:
        for file in os.listdir(os.path.join('test', 'morf_analyysid')):
            if file.endswith('.txt'):
                file_id = str(file).split('_')[1][2:]
                with open(os.path.join('test', 'morf_analyysid', file), 'r', encoding='UTF-8') as f:
                    text = preprocess_text(Text(f.read()))
                
                nertagger.tag(text)
                text.add_layer(flatten(text['ner'], 'flat_ner'))
                
                word_level_ner.tag(text)
                text.add_layer(flatten(text['wordner'], 'flat_wordner'))
                
                
                for x in removed_layers:
                    text.pop_layer(x)
                    
                for file in testing_files:
                    if f'id{file_id}' in file:
                        text_to_json(text, file=os.path.join(path, file))
                        print(f'Märgendatud fail {file}')
    else:
        iterator = 0
        for test_file in testing_files:
            with open(find(test_file.replace('.json', '.txt'), 'test'), 'r', encoding='UTF-8') as f:
                text = preprocess_text(Text(f.read()))

            nertagger.tag(text)
            text.add_layer(flatten(text['ner'], 'flat_ner'))
            
            word_level_ner.tag(text)
            text.add_layer(flatten(text['wordner'], 'flat_wordner'))
            
            for x in removed_layers:
                text.pop_layer(x)

            text_to_json(text, file=os.path.join(path, test_file))

            print(f'Märgendatud fail {test_file}')
            iterator += 1
    print(f"(!) Programm on lõpetanud")

# %%
def get_testing_files():
    files = []
    for file in os.listdir(os.path.join('test', 'flattened_json_files')):
        if file.endswith('.json'):
            files.append(file)
    return files

# %%
testing_files = get_testing_files()
model_dir = os.path.join('models', 'model_gaz_loc')
is_tsv = False

tag_files(testing_files, model_dir, is_tsv)

extract_results('model_gaz_loc', testing_files)
# Out:
# (!) Alustan failide märgendamist
# Märgendatud fail Harju_Hageri_Kohila_id8179_1871a.json
# Märgendatud fail Harju_Hageri_Kohila_id8352_1874a.json
# Märgendatud fail Harju_J6el2htme_J6el2htme_id7155_1868a.json
# Märgendatud fail Harju_J6el2htme_J6el2htme_id7376_1869a.json
# Märgendatud fail Harju_J6el2htme_J6el2htme_id7637_1870a.json
# Märgendatud fail Harju_Juuru_Kaiu_id18361_1873a.json
# Märgendatud fail Harju_Juuru_Kaiu_id18707_1874a.json
# Märgendatud fail Harju_Kose_Habaja_id678_1874a.json
# Märgendatud fail Harju_Kose_Habaja_id808_1874a.json
# Märgendatud fail Harju_Kose_Kose-Uuem6isa_id12761_1870a.json
# Märgendatud fail Harju_Kose_Kose-Uuem6isa_id13306_1870a.json
# Märgendatud fail Harju_Kose_Kose-Uuem6isa_id1775_1867a.json
# Märgendatud fail Harju_Kose_Kose-Uuem6isa_id1834_1867a.json
# Märgendatud fail Harju_Kose_Kose-Uuem6isa_id3956_1868a.json
# Märgendatud fail Harju_Kose_Kose-Uuem6isa_id4927_1868a.json
# Märgendatud fail Harju_Kose_Palvere_id25212_1873a.json
# Märgendatud fail Harju_Kose_Triigi_id13811_1872a.json
# Märgendatud fail Harju_Kose_Triigi_id9228_1866a.json
# Märgendatud fail Harju_Rapla_Rapla_id19155_1870a.json
# Märgendatud fail Harju_Rapla_Rapla_id19159_1870a.json
# Märgendatud fail Harju_Rapla_Rapla_id20936_1870a.json
# Märgendatud fail Harju_Rapla_Rapla_id22193_1871a.json
# Märgendatud fail Harju_Rapla_Rapla_id23345_1872a.json
# Märgendatud fail Harju_Rapla_Rapla_id23362_1873a.json
# Märgendatud fail J2rva_Ambla_Uudekyla_id13869_1868a.json
# Märgendatud fail J2rva_Ambla_Uudekyla_id13871_1869a.json
# Märgendatud fail J2rva_Anna_Purdi_id24611_1870a.json
# Märgendatud fail J2rva_Anna_Purdi_id24750_1870a.json
# Märgendatud fail J2rva_J2rva-Jaani_Einmanni_id10150_1868a.json
# Märgendatud fail J2rva_J2rva-Jaani_Einmanni_id12003_1869a.json
# Märgendatud fail J2rva_J2rva-Jaani_Einmanni_id13619_1870a.json
# Märgendatud fail J2rva_J2rva-Jaani_Einmanni_id14853_1870a.json
# Märgendatud fail J2rva_Peetri_V2ike-Kareda_id19059_1867a.json
# Märgendatud fail J2rva_Peetri_V2ike-Kareda_id19251_1870a.json
# Märgendatud fail J2rva_Peetri_V2ike-Kareda_id19278_1871a.json
# Märgendatud fail J2rva_Peetri_V2ike-Kareda_id19563_1871a.json
# Märgendatud fail J2rva_Peetri_V2ike-Kareda_id22366_1880a.json
# Märgendatud fail J2rva_Peetri_V2ike-Kareda_id22452_1881a.json
# Märgendatud fail J2rva_Tyri_Kirna_id22750_1868a.json
# Märgendatud fail J2rva_Tyri_Kirna_id22864_1869a.json
# Märgendatud fail J2rva_Tyri_Kirna_id22900_1869a.json
# Märgendatud fail J2rva_Tyri_Kirna_id22955_1870a.json
# Märgendatud fail J2rva_Tyri_Kirna_id23180_1871a.json
# Märgendatud fail J2rva_Tyri_Kirna_id23190_1871a.json
# Märgendatud fail J2rva_Tyri_Kirna_id23278_1872a.json
# Märgendatud fail J2rva_Tyri_Kirna_id23561_1873a.json
# Märgendatud fail J2rva_Tyri_Kirna_id23625_1873a.json
# Märgendatud fail L22ne_Kullamaa_K22nda_id19769_1873a.json
# Märgendatud fail L22ne_Kullamaa_Kuij6e_id15173_1869a.json
# Märgendatud fail L22ne_Kullamaa_Piirsalu_id6008_1872a.json
# Märgendatud fail L22ne_Kullamaa_Teenuse_id9835_1870a.json
# Märgendatud fail L22ne_Martna_Martna_id15270_1870a.json
# Märgendatud fail L22ne_Pyhalepa_K2rdla_id23216_1873a.json
# Märgendatud fail L22ne_Pyhalepa_K2rdla_id23485_1873a.json
# Märgendatud fail L22ne_Pyhalepa_K2rdla_id23495_1874a.json
# Märgendatud fail L22ne_Pyhalepa_K2rdla_id23509_1874a.json
# Märgendatud fail L22ne_Pyhalepa_K2rdla_id23851_1875a.json
# Märgendatud fail L22ne_Pyhalepa_K2rdla_id24190_1876a.json
# Märgendatud fail L22ne_Pyhalepa_K2rdla_id24200_1876a.json
# Märgendatud fail L22ne_Pyhalepa_K2rdla_id24379_1876a.json
# Märgendatud fail L22ne_Pyhalepa_K2rdla_id24380_1876a.json
# Märgendatud fail L22ne_Pyhalepa_K2rdla_id24799_1876a.json
# Märgendatud fail L22ne_Pyhalepa_K2rdla_id25053_1877a.json
# Märgendatud fail L22ne_Pyhalepa_K2rdla_id25094_1877a.json
# Märgendatud fail L22ne_Pyhalepa_K2rdla_id25450_1877a.json
# Märgendatud fail L22ne_Pyhalepa_Kassari_id23857_1869a.json
# Märgendatud fail L22ne_Ridala_Kiideva_id7899_1867a.json
# Märgendatud fail L22ne_Ridala_Kiideva_id7994_1874a.json
# Märgendatud fail L22ne_Ridala_Kiideva_id8018_1874a.json
# Märgendatud fail L22ne_Vormsi_Vormsi_id15009_1890a.json
# Märgendatud fail P2rnu_Halliste_Pornuse_id2303_1868a.json
# Märgendatud fail P2rnu_Halliste_Pornuse_id2908_1868a.json
# Märgendatud fail P2rnu_Halliste_Pornuse_id2913_1868a.json
# Märgendatud fail P2rnu_Halliste_Pornuse_id3477_1868a.json
# Märgendatud fail P2rnu_Halliste_Pornuse_id4528_1869a.json
# Märgendatud fail P2rnu_Halliste_Pornuse_id4993_1869a.json
# Märgendatud fail P2rnu_P2rnu-Elisabethi_Sauga_id17780_1868a.json
# Märgendatud fail P2rnu_P2rnu-Elisabethi_Sauga_id17792_1868a.json
# Märgendatud fail P2rnu_P2rnu-Elisabethi_Sauga_id17830_1868a.json
# Märgendatud fail P2rnu_P2rnu-Elisabethi_Sauga_id17833_1869a.json
# Märgendatud fail P2rnu_Saarde_Laiksaare_id23152_1858a.json
# Märgendatud fail P2rnu_T6stamaa_Kihnu_id25088_1843a.json
# Märgendatud fail P2rnu_T6stamaa_Kihnu_id25320_1846a.json
# Märgendatud fail P2rnu_T6stamaa_Kihnu_id292_1843a.json
# Märgendatud fail P2rnu_Tori_Sindi_id19856_1834a.json
# Märgendatud fail P2rnu_Tori_Sindi_id5355_1833a.json
# Märgendatud fail P2rnu_Tori_Sindi_id6648_1833a.json
# Märgendatud fail Saare_K2rla_K2rla_id5729_1827a.json
# Märgendatud fail Saare_K2rla_K2rla_id5731_1827a.json
# Märgendatud fail Saare_K2rla_K2rla_id7172_1828a.json
# Märgendatud fail Saare_Kaarma_Loona_id359_1885a.json
# Märgendatud fail Saare_Kihelkonna_Atla_id6876_1872a.json
# Märgendatud fail Saare_Kihelkonna_Atla_id7555_1875a.json
# Märgendatud fail Saare_Kihelkonna_Atla_id7559_1875a.json
# Märgendatud fail Saare_Kihelkonna_Kihelkonna_id22212_1883a.json
# Märgendatud fail Saare_Kihelkonna_Kihelkonna_id22724_1884a.json
# Märgendatud fail Saare_Kihelkonna_Kihelkonna_id22741_1885a.json
# Märgendatud fail Saare_Kihelkonna_Kotlandi_id18384_1864a.json
# Märgendatud fail Saare_Kihelkonna_Kotlandi_id19661_1866a.json
# Märgendatud fail Saare_Kihelkonna_Kotlandi_id19702_1866a.json
# Märgendatud fail Saare_Kihelkonna_Kotlandi_id20010_1866a.json
# Märgendatud fail Saare_Kihelkonna_Kotlandi_id20012_1866a.json
# Märgendatud fail Saare_Kihelkonna_Kotlandi_id20016_1867a.json
# Märgendatud fail Saare_Kihelkonna_Kotlandi_id20733_1867a.json
# Märgendatud fail Saare_Kihelkonna_Kotlandi_id20754_1867a.json
# Märgendatud fail Saare_Kihelkonna_Kotlandi_id20950_1869a.json
# Märgendatud fail Saare_Kihelkonna_Kotlandi_id21551_1869a.json
# Märgendatud fail Saare_Kihelkonna_Kotlandi_id21644_1869a.json
# Märgendatud fail Saare_Kihelkonna_Lymanda_id1409_1868a.json
# Märgendatud fail Saare_Kihelkonna_Lymanda_id2951_1832a.json
# Märgendatud fail Saare_Kihelkonna_Lymanda_id5723_1833a.json
# Märgendatud fail Saare_Kihelkonna_Lymanda_id7315_1833a.json
# Märgendatud fail Saare_Kihelkonna_Lymanda_id7352_1833a.json
# Märgendatud fail Saare_Kihelkonna_Lymanda_id803_1868a.json
# Märgendatud fail Saare_Kihelkonna_Lymanda_id8133_1833a.json
# Märgendatud fail Tartu_R6ngu_Aakre_id14885_1830a.json
# Märgendatud fail Tartu_R6ngu_Aakre_id14919_1830a.json
# Märgendatud fail Tartu_Sangaste_Kuigatsi_id16101_1872a.json
# Märgendatud fail Tartu_Sangaste_Kuigatsi_id16366_1872a.json
# Märgendatud fail Tartu_Sangaste_Kuigatsi_id16506_1872a.json
# Märgendatud fail Tartu_V6nnu_Ahja_id12070_1873a.json
# Märgendatud fail Tartu_V6nnu_Ahja_id12437_1875a.json
# Märgendatud fail Tartu_V6nnu_Kiidj2rve_id24429_1866a.json
# Märgendatud fail Tartu_V6nnu_Kiidj2rve_id24498_1866a.json
# Märgendatud fail Tartu_V6nnu_Kiidj2rve_id24501_1866a.json
# Märgendatud fail Tartu_V6nnu_Kiidj2rve_id24502_1866a.json
# Märgendatud fail Tartu_V6nnu_Kiidj2rve_id24585_1866a.json
# Märgendatud fail Tartu_V6nnu_Kiidj2rve_id24651_1866a.json
# Märgendatud fail Tartu_V6nnu_Kiidj2rve_id24726_1866a.json
# Märgendatud fail Tartu_V6nnu_Kiidj2rve_id24728_1866a.json
# Märgendatud fail Tartu_V6nnu_Kiidj2rve_id24731_1866a.json
# Märgendatud fail Tartu_V6nnu_Kiidj2rve_id24734_1866a.json
# Märgendatud fail Tartu_V6nnu_Kiidj2rve_id24771_1867a.json
# Märgendatud fail Tartu_V6nnu_Kiidj2rve_id24774_1867a.json
# Märgendatud fail Tartu_V6nnu_Kiidj2rve_id24789_1867a.json
# Märgendatud fail Tartu_V6nnu_Kiidj2rve_id24844_1867a.json
# Märgendatud fail Tartu_V6nnu_Kiidj2rve_id24886_1868a.json
# Märgendatud fail Tartu_V6nnu_Kiidj2rve_id24954_1868a.json
# Märgendatud fail Tartu_V6nnu_Kiidj2rve_id24994_1869a.json
# Märgendatud fail Tartu_V6nnu_Kiidj2rve_id25080_1870a.json
# Märgendatud fail Tartu_V6nnu_Kiidj2rve_id25085_1870a.json
# Märgendatud fail V6ru_R2pina_Kahkva_id19841_1867a.json
# Märgendatud fail V6ru_R2pina_Kahkva_id20116_1867a.json
# Märgendatud fail V6ru_R2pina_Kahkva_id21297_1867a.json
# Märgendatud fail V6ru_R2pina_Kahkva_id23081_1867a.json
# Märgendatud fail V6ru_R2pina_Kahkva_id23759_1867a.json
# Märgendatud fail V6ru_R2pina_Kahkva_id24435_1868a.json
# Märgendatud fail V6ru_R2pina_Kahkva_id24976_1868a.json
# Märgendatud fail V6ru_R2pina_R2pina_id10269_1870a.json
# Märgendatud fail V6ru_R2pina_R2pina_id10283_1870a.json
# Märgendatud fail V6ru_R2pina_R2pina_id10705_1868a.json
# Märgendatud fail V6ru_R2pina_R2pina_id14382_1867a.json
# Märgendatud fail V6ru_R2pina_R2pina_id14687_1867a.json
# Märgendatud fail V6ru_R2pina_R2pina_id9286_1869a.json
# Märgendatud fail V6ru_R2pina_R2pina_id9301_1869a.json
# Märgendatud fail V6ru_R6uge_Saaluse_id10087_1879a.json
# Märgendatud fail V6ru_R6uge_Saaluse_id10144_1879a.json
# Märgendatud fail V6ru_R6uge_Saaluse_id10650_1879a.json
# Märgendatud fail V6ru_R6uge_Saaluse_id10756_1879a.json
# Märgendatud fail V6ru_R6uge_Saaluse_id10810_1879a.json
# Märgendatud fail V6ru_R6uge_Saaluse_id10814_1879a.json
# Märgendatud fail V6ru_R6uge_Saaluse_id10818_1879a.json
# Märgendatud fail V6ru_R6uge_Saaluse_id9506_1878a.json
# Märgendatud fail V6ru_R6uge_Saaluse_id9676_1878a.json
# Märgendatud fail V6ru_R6uge_Saaluse_id9723_1878a.json
# Märgendatud fail V6ru_R6uge_Saaluse_id9775_1878a.json
# Märgendatud fail V6ru_Urvaste_Urvaste_id7577_1859a.json
# Märgendatud fail V6ru_Urvaste_Urvaste_id7592_1859a.json
# Märgendatud fail V6ru_Urvaste_Urvaste_id8025_1859a.json
# Märgendatud fail V6ru_Urvaste_Urvaste_id9128_1860a.json
# Märgendatud fail V6ru_Urvaste_Vaabina_id390_1876a.json
# Märgendatud fail V6ru_Vastseliina_Misso_id13579_1881a.json
# Märgendatud fail V6ru_Vastseliina_Misso_id13935_1881a.json
# Märgendatud fail V6ru_Vastseliina_Misso_id15197_1882a.json
# Märgendatud fail V6ru_Vastseliina_Misso_id20282_1882a.json
# Märgendatud fail V6ru_Vastseliina_Misso_id20432_1882a.json
# Märgendatud fail V6ru_Vastseliina_Misso_id20684_1882a.json
# Märgendatud fail V6ru_Vastseliina_Misso_id21738_1883a.json
# Märgendatud fail V6ru_Vastseliina_Misso_id7948_1885a.json
# Märgendatud fail Viljandi_P6ltsamaa_Adavere_id20042_1872a.json
# Märgendatud fail Viljandi_P6ltsamaa_Pajusi_id1908_1869a.json
# Märgendatud fail Viljandi_P6ltsamaa_Pajusi_id2401_1870a.json
# Märgendatud fail Viljandi_P6ltsamaa_Pajusi_id2436_1870a.json
# Märgendatud fail Viljandi_P6ltsamaa_Pajusi_id5269_1872a.json
# Märgendatud fail Viljandi_P6ltsamaa_Pajusi_id7099_1871a.json
# Märgendatud fail Viljandi_P6ltsamaa_Pajusi_id9876_1874a.json
# Märgendatud fail Viljandi_P6ltsamaa_Uue-P6ltsamaa_id8547_1853a.json
# Märgendatud fail Viljandi_P6ltsamaa_Uue-P6ltsamaa_id8568_1853a.json
# Märgendatud fail Viljandi_P6ltsamaa_Uue-P6ltsamaa_id8876_1854a.json
# Märgendatud fail Viljandi_P6ltsamaa_Uue-P6ltsamaa_id8905_1854a.json
# Märgendatud fail Viljandi_Paistu_Holstre_id11608_1848a.json
# Märgendatud fail Viljandi_Paistu_Holstre_id11654_1848a.json
# Märgendatud fail Viljandi_Paistu_Holstre_id1456_1825a.json
# Märgendatud fail Viljandi_Paistu_Holstre_id2308_1825a.json
# Märgendatud fail Viljandi_Paistu_Holstre_id2546_1825a.json
# Märgendatud fail Viljandi_Paistu_Holstre_id3148_1827a.json
# Märgendatud fail Viljandi_Paistu_Holstre_id514_1843a.json
# Märgendatud fail Viljandi_Paistu_Holstre_id516_1843a.json
# Märgendatud fail Viljandi_Paistu_Holstre_id520_1843a.json
# Märgendatud fail Viljandi_Paistu_Holstre_id521_1843a.json
# Märgendatud fail Viljandi_Paistu_Holstre_id532_1843a.json
# Märgendatud fail Viljandi_Paistu_Holstre_id8703_1835a.json
# Märgendatud fail Viljandi_Paistu_Holstre_id8705_1835a.json
# Märgendatud fail Viljandi_Pilistvere_Arussaare_id23636_1848a.json
# Märgendatud fail Viljandi_Pilistvere_Arussaare_id23684_1848a.json
# Märgendatud fail Viljandi_Pilistvere_Arussaare_id23687_1849a.json
# Märgendatud fail Viljandi_Pilistvere_Arussaare_id23695_1851a.json
# Märgendatud fail Viljandi_Pilistvere_Arussaare_id448_1841a.json
# Märgendatud fail Viljandi_Pilistvere_Arussaare_id451_1841a.json
# Märgendatud fail Viljandi_Pilistvere_Arussaare_id454_1841a.json
# Märgendatud fail Viljandi_Viljandi_Karula_id19416_1868a.json
# Märgendatud fail Viru_Haljala_Vihula_id10044_1881a.json
# Märgendatud fail Viru_Haljala_Vihula_id4021_1875a.json
# Märgendatud fail Viru_Haljala_Vihula_id4382_1875a.json
# Märgendatud fail Viru_Haljala_Vihula_id4961_1876a.json
# Märgendatud fail Viru_Haljala_Vihula_id8453_1878a.json
# Märgendatud fail Viru_Haljala_Vihula_id8462_1878a.json
# Märgendatud fail Viru_Iisaku_Iisaku_id3170_1886a.json
# Märgendatud fail Viru_Iisaku_Pootsiku_id8862_1880a.json
# Märgendatud fail Viru_Iisaku_Pootsiku_id8868_1880a.json
# Märgendatud fail Viru_J6hvi_Illuka_id2664_1873a.json
# Märgendatud fail Viru_Kadrina_Hulja_id1630_1881a.json
# Märgendatud fail Viru_Kadrina_T6dva-K6nnu_id12822_1867a.json
# Märgendatud fail Viru_Lyganuse_Pyssi_id991_1905a.json
# Märgendatud fail Viru_Rakvere_S6meru_id10487_1883a.json
# Märgendatud fail Viru_Rakvere_S6meru_id10983_1883a.json
# Märgendatud fail Viru_Rakvere_S6meru_id10987_1883a.json
# Märgendatud fail Viru_Rakvere_S6meru_id2607_1882a.json
# (!) Programm on lõpetanud
# [[{'label': 'PER', 'start': 18, 'end': 30}, {'label': 'PER', 'start': 32, 'end': 46}, {'label': 'PER', 'start': 67, 'end': 80}, {'label': 'PER', 'start': 84, 'end': 98}, {'label': 'PER', 'start': 131, 'end': 136}, {'label': 'LOC', 'start': 194, 'end': 202}, {'label': 'LOC_ORG', 'start': 203, 'end': 208}, {'label': 'PER', 'start': 209, 'end': 217}, {'label': 'PER', 'start': 219, 'end': 233}, {'label': 'PER', 'start': 381, 'end': 395}, {'label': 'LOC_ORG', 'start': 439, 'end': 444}, {'label': 'PER', 'start': 445, 'end': 452}, {'label': 'PER', 'start': 558, 'end': 573}, {'label': 'PER', 'start': 695, 'end': 703}, {'label': 'PER', 'start': 751, 'end': 764}, {'label': 'PER', 'start': 863, 'end': 877}, {'label': 'PER', 'start': 984, 'end': 998}, {'label': 'PER', 'start': 1000, 'end': 1013}, {'label': 'LOC_ORG', 'start': 1033, 'end': 1044}, {'label': 'PER', 'start': 1049, 'end': 1064}, {'label': 'LOC', 'start': 1074, 'end': 1086}, {'label': 'LOC_ORG', 'start': 1103, 'end': 1110}, {'label': 'PER', 'start': 1111, 'end': 1118}, {'label': 'PER', 'start': 1133, 'end': 1137}, {'label': 'PER', 'start': 1138, 'end': 1148}, {'label': 'PER', 'start': 1203, 'end': 1217}, {'label': 'PER', 'start': 1366, 'end': 1380}, {'label': 'PER', 'start': 1470, 'end': 1487}, {'label': 'PER', 'start': 1565, 'end': 1581}, {'label': 'PER', 'start': 1585, 'end': 1597}, {'label': 'PER', 'start': 1602, 'end': 1618}, {'label': 'PER', 'start': 1631, 'end': 1640}], [{'label': 'PER', 'start': 18, 'end': 33}, {'label': 'PER', 'start': 535, 'end': 540}, {'label': 'PER', 'start': 547, 'end': 551}, {'label': 'PER', 'start': 751, 'end': 755}, {'label': 'PER', 'start': 925, 'end': 929}, {'label': 'PER', 'start': 1114, 'end': 1123}, {'label': 'PER', 'start': 1139, 'end': 1143}, {'label': 'PER', 'start': 1155, 'end': 1169}, {'label': 'PER', 'start': 1216, 'end': 1225}], [{'label': 'PER', 'start': 1, 'end': 11}, {'label': 'PER', 'start': 39, 'end': 50}, {'label': 'PER', 'start': 90, 'end': 100}, {'label': 'PER', 'start': 128, 'end': 133}, {'label': 'PER', 'start': 209, 'end': 215}, {'label': 'PER', 'start': 264, 'end': 269}, {'label': 'PER', 'start': 296, 'end': 301}, {'label': 'PER', 'start': 307, 'end': 312}, {'label': 'LOC_ORG', 'start': 389, 'end': 405}, {'label': 'PER', 'start': 418, 'end': 432}, {'label': 'PER', 'start': 494, 'end': 499}, {'label': 'PER', 'start': 587, 'end': 593}, {'label': 'PER', 'start': 616, 'end': 624}, {'label': 'PER', 'start': 703, 'end': 708}, {'label': 'PER', 'start': 709, 'end': 715}, {'label': 'PER', 'start': 812, 'end': 818}, {'label': 'PER', 'start': 819, 'end': 824}, {'label': 'LOC_ORG', 'start': 884, 'end': 889}, {'label': 'PER', 'start': 890, 'end': 902}, {'label': 'PER', 'start': 945, 'end': 950}, {'label': 'PER', 'start': 951, 'end': 957}, {'label': 'PER', 'start': 984, 'end': 989}, {'label': 'PER', 'start': 993, 'end': 998}, {'label': 'PER', 'start': 1044, 'end': 1059}, {'label': 'PER', 'start': 1060, 'end': 1065}, {'label': 'PER', 'start': 1096, 'end': 1107}, {'label': 'PER', 'start': 1220, 'end': 1225}, {'label': 'PER', 'start': 1332, 'end': 1342}, {'label': 'LOC_ORG', 'start': 1350, 'end': 1361}, {'label': 'PER', 'start': 1438, 'end': 1449}, {'label': 'PER', 'start': 1504, 'end': 1508}, {'label': 'PER', 'start': 1530, 'end': 1542}], [{'label': 'LOC', 'start': 11, 'end': 29}, {'label': 'LOC_ORG', 'start': 30, 'end': 37}, {'label': 'PER', 'start': 38, 'end': 51}, {'label': 'PER', 'start': 58, 'end': 62}, {'label': 'PER', 'start': 81, 'end': 93}, {'label': 'PER', 'start': 103, 'end': 108}, {'label': 'PER', 'start': 298, 'end': 304}, {'label': 'PER', 'start': 332, 'end': 344}, {'label': 'PER', 'start': 372, 'end': 376}, {'label': 'PER', 'start': 419, 'end': 424}, {'label': 'PER', 'start': 678, 'end': 683}, {'label': 'PER', 'start': 728, 'end': 732}, {'label': 'PER', 'start': 851, 'end': 860}, {'label': 'PER', 'start': 861, 'end': 866}, {'label': 'PER', 'start': 924, 'end': 929}, {'label': 'PER', 'start': 1032, 'end': 1037}, {'label': 'P ...
# (!) Tulemused arvutatud
# (!) Tulemused kirjutatud faili <_io.TextIOWrapper name='models\\model_gaz_loc\\results.txt' mode='w+' encoding='cp1252'>
# ({'ent_type': {'correct': 5508,
#    'incorrect': 327,
#    'partial': 0,
#    'missed': 791,
#    'spurious': 311,
#    'possible': 6626,
#    'actual': 6146,
#    'precision': 0.8961926456231696,
#    'recall': 0.8312707515846665,
#    'f1': 0.8625117444409646},
#   'partial': {'correct': 5306,
#    'incorrect': 0,
#    'partial': 529,
#    'missed': 791,
#    'spurious': 311,
#    'possible': 6626,
#    'actual': 6146,
#    'precision': 0.9063618613732509,
#    'recall': 0.8407032900694235,
#    'f1': 0.8722987785781396},
#   'strict': {'correct': 5189,
#    'incorrect': 646,
#    'partial': 0,
#    'missed': 791,
#    'spurious': 311,
#    'possible': 6626,
#    'actual': 6146,
#    'precision': 0.8442889684347543,
#    'recall': 0.7831270751584667,
#    'f1': 0.8125587222048231},
#   'exact': {'correct': 5306,
#    'incorrect': 529,
#    'partial': 0,
#    'missed': 791,
#    'spurious': 311,
#    'possible': 6626,
#    'actual': 6146,
#    'precision': 0.8633257403189066,
#    'recall': 0.8007847872019318,
#    'f1': 0.8308800501096147}},
#  {'ORG': {'ent_type': {'correct': 30,
#     'incorrect': 22,
#     'partial': 0,
#     'missed': 14,
#     'spurious': 10,
#     'possible': 66,
#     'actual': 62,
#     'precision': 0.4838709677419355,
#     'recall': 0.45454545454545453,
#     'f1': 0.46874999999999994},
#    'partial': {'correct': 33,
#     'incorrect': 0,
#     'partial': 19,
#     'missed': 14,
#     'spurious': 10,
#     'possible': 66,
#     'actual': 62,
#     'precision': 0.6854838709677419,
#     'recall': 0.6439393939393939,
#     'f1': 0.6640625},
#    'strict': {'correct': 28,
#     'incorrect': 24,
#     'partial': 0,
#     'missed': 14,
#     'spurious': 10,
#     'possible': 66,
#     'actual': 62,
#     'precision': 0.45161290322580644,
#     'recall': 0.42424242424242425,
#     'f1': 0.4375},
#    'exact': {'correct': 33,
#     'incorrect': 19,
#     'partial': 0,
#     'missed': 14,
#     'spurious': 10,
#     'possible': 66,
#     'actual': 62,
#     'precision': 0.532258064516129,
#     'recall': 0.5,
#     'f1': 0.515625}},
#   'PER': {'ent_type': {'correct': 4898,
#     'incorrect': 37,
#     'partial': 0,
#     'missed': 401,
#     'spurious': 217,
#     'possible': 5336,
#     'actual': 5152,
#     'precision': 0.9506987577639752,
#     'recall': 0.9179160419790104,
#     'f1': 0.9340198321891685},
#    'partial': {'correct': 4642,
#     'incorrect': 0,
#     'partial': 293,
#     'missed': 401,
#     'spurious': 217,
#     'possible': 5336,
#     'actual': 5152,
#     'precision': 0.9294448757763976,
#     'recall': 0.8973950524737632,
#     'f1': 0.91313882532418},
#    'strict': {'correct': 4625,
#     'incorrect': 310,
#     'partial': 0,
#     'missed': 401,
#     'spurious': 217,
#     'possible': 5336,
#     'actual': 5152,
#     'precision': 0.8977096273291926,
#     'recall': 0.8667541229385307,
#     'f1': 0.8819603356216629},
#    'exact': {'correct': 4642,
#     'incorrect': 293,
#     'partial': 0,
#     'missed': 401,
#     'spurious': 217,
#     'possible': 5336,
#     'actual': 5152,
#     'precision': 0.9010093167701864,
#     'recall': 0.8699400299850075,
#     'f1': 0.8852021357742182}},
#   'MISC': {'ent_type': {'correct': 10,
#     'incorrect': 8,
#     'partial': 0,
#     'missed': 10,
#     'spurious': 1,
#     'possible': 28,
#     'actual': 19,
#     'precision': 0.5263157894736842,
#     'recall': 0.35714285714285715,
#     'f1': 0.425531914893617},
#    'partial': {'correct': 6,
#     'incorrect': 0,
#     'partial': 12,
#     'missed': 10,
#     'spurious': 1,
#     'possible': 28,
#     'actual': 19,
#     'precision': 0.631578947368421,
#     'recall': 0.42857142857142855,
#     'f1': 0.5106382978723404},
#    'strict': {'correct': 5,
#     'incorrect': 13,
#     'partial': 0,
#     'missed': 10,
#     'spurious': 1,
#     'possible': 28,
#     'actual': 19,
#     'precision': 0.2631578947368421,
#     'recall': 0.17857142857142858,
#     'f1': 0.2127659574468085},
#    'exact': {'correct': 6,
#     'incorrect': 12,
#     'partial': 0,
#     'missed': 10,
#     'spurious': 1,
#     'possible': 28,
#     'actual': 19,
#     'precision': 0.3157894736842105,
#     'recall': 0.21428571428571427,
#     'f1': 0.2553191489361702}},
#   'LOC': {'ent_type': {'correct': 86,
#     'incorrect': 106,
#     'partial': 0,
#     'missed': 167,
#     'spurious': 29,
#     'possible': 359,
#     'actual': 221,
#     'precision': 0.3891402714932127,
#     'recall': 0.2395543175487465,
#     'f1': 0.296551724137931},
#    'partial': {'correct': 131,
#     'incorrect': 0,
#     'partial': 61,
#     'missed': 167,
#     'spurious': 29,
#     'possible': 359,
#     'actual': 221,
#     'precision': 0.7307692307692307,
#     'recall': 0.44986072423398327,
#     'f1': 0.5568965517241379},
#    'strict': {'correct': 78,
#     'incorrect': 114,
#     'partial': 0,
#     'missed': 167,
#     'spurious': 29,
#     'possible': 359,
#     'actual': 221,
#     'precision': 0.35294117647058826,
#     'recall': 0.21727019498607242,
#     'f1': 0.2689655172413793},
#    'exact': {'correct': 131,
#     'incorrect': 61,
#     'partial': 0,
#     'missed': 167,
#     'spurious': 29,
#     'possible': 359,
#     'actual': 221,
#     'precision': 0.5927601809954751,
#     'recall': 0.3649025069637883,
#     'f1': 0.4517241379310345}},
#   'LOC_ORG': {'ent_type': {'correct': 484,
#     'incorrect': 154,
#     'partial': 0,
#     'missed': 199,
#     'spurious': 54,
#     'possible': 837,
#     'actual': 692,
#     'precision': 0.6994219653179191,
#     'recall': 0.5782556750298686,
#     'f1': 0.6330935251798562},
#    'partial': {'correct': 494,
#     'incorrect': 0,
#     'partial': 144,
#     'missed': 199,
#     'spurious': 54,
#     'possible': 837,
#     'actual': 692,
#     'precision': 0.8179190751445087,
#     'recall': 0.6762246117084827,
#     'f1': 0.7403531720078482},
#    'strict': {'correct': 453,
#     'incorrect': 185,
#     'partial': 0,
#     'missed': 199,
#     'spurious': 54,
#     'possible': 837,
#     'actual': 692,
#     'precision': 0.6546242774566474,
#     'recall': 0.5412186379928315,
#     'f1': 0.592544146500981},
#    'exact': {'correct': 494,
#     'incorrect': 144,
#     'partial': 0,
#     'missed': 199,
#     'spurious': 54,
#     'possible': 837,
#     'actual': 692,
#     'precision': 0.7138728323699421,
#     'recall': 0.5902031063321386,
#     'f1': 0.6461739699149771}}})
