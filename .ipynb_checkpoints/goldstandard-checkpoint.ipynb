# %%
import os
import re

from estnltk import Text, Layer
from estnltk.taggers import NerTagger

nertagger = NerTagger()

# %%
with open("vallakohus_esimene\Harju_Hageri_Kohila_id20604_1883a.ann", encoding="UTF8") as annotated_file:
    annotation = annotated_file.read()
with open("vallakohus_esimene\Harju_Hageri_Kohila_id20604_1883a.txt", encoding="UTF8") as txt:
    textfile = txt.read()

# %%
print(annotation)
# Out:
# T1	Isik 34 42	J. Krais
# T2	Isik 56 72	Juhan Lesserberg
# T3	Isik 76 86	Juhan Asse
# T4	Isik 146 158	J.Lesserberg
# T5	Isik 190 200	Juhan Asse
# T6	Isik 231 241	Lesserberg
# T7	Isik 357 373	Juhan Lesserberg
# T8	Isik 418 428	Juhan Asse
# T9	Isik 584 600	Juhan Lesserberg
# T10	Isik 740 750	Juhan Asse

# %%
# converting the text form .txt file into an EstNLTK Text object
text = Text(textfile)
text = text.tag_layer(['sentences', 'morph_analysis'])

# %%
text.pop_layer('compound_tokens')
text.pop_layer('morph_analysis')
text.pop_layer('sentences')
text.pop_layer('words')
# Out:
# Layer(name='words', attributes=('normalized_form',), spans=SL[Span('Astus', [{'normalized_form': None}]),
# Span('kohtu', [{'normalized_form': None}]),
# Span('ette', [{'normalized_form': None}]),
# Span('Koolivöörmünder', [{'normalized_form': None}]),
# Span('J. Krais', [{'normalized_form': 'J. Krais'}]),
# Span('ja', [{'normalized_form': None}]),
# Span('kaebas', [{'normalized_form': None}]),
# Span('et', [{'normalized_form': None}]),
# Span('Juhan', [{'normalized_form': None}]),
# Span('Lesserberg', [{'normalized_form': None}]),
# Span('ja', [{'normalized_form': None}]),
# Span('Juhan', [{'normalized_form': None}]),
# Span('Asse', [{'normalized_form': None}]),
# Span('olla', [{'normalized_form': None}]),
# Span('kolimaia', [{'normalized_form': None}]),
# Span('ükse', [{'normalized_form': None}]),
# Span('ees', [{'normalized_form': None}]),
# Span('rielnud', [{'normalized_form': None}]),
# Span('ja', [{'normalized_form': None}]),
# Span('peale', [{'normalized_form': None}]),
# Span('riiu', [{'normalized_form': None}]),
# Span('lahutust', [{'normalized_form': None}]),
# Span('olla', [{'normalized_form': None}]),
# Span('J.Lesserberg', [{'normalized_form': 'J.Lesserberg'}]),
# Span('hirmsaste', [{'normalized_form': None}]),
# Span('sõimand', [{'normalized_form': None}]),
# Span('ja', [{'normalized_form': None}]),
# Span('vandund', [{'normalized_form': None}]),
# Span('.', [{'normalized_form': None}]),
# Span('Juhan', [{'normalized_form': None}]),
# Span('Asse', [{'normalized_form': None}]),
# Span('sai', [{'normalized_form': None}]),
# Span('ette', [{'normalized_form': None}]),
# Span('kutsutud', [{'normalized_form': None}]),
# Span('tunistas', [{'normalized_form': None}]),
# Span('et', [{'normalized_form': None}]),
# Span('Lesserberg', [{'normalized_form': None}]),
# Span('olla', [{'normalized_form': None}]),
# Span('teda', [{'normalized_form': None}]),
# Span('lükanud', [{'normalized_form': None}]),
# Span('selle', [{'normalized_form': None}]),
# Span('peale', [{'normalized_form': None}]),
# Span('olla', [{'normalized_form': None}]),
# Span('nemad', [{'normalized_form': None}]),
# Span('karvupidi', [{'normalized_form': None}]),
# Span('kokku', [{'normalized_form': None}]),
# Span('juhtunud', [{'normalized_form': None}]),
# Span('ja', [{'normalized_form': None}]),
# Span('teine', [{'normalized_form': None}]),
# Span('teist', [{'normalized_form': None}]),
# Span('hilma', [{'normalized_form': None}]),
# Span('wiga', [{'normalized_form': None}]),
# Span('tegemata', [{'normalized_form': None}]),
# Span('maha', [{'normalized_form': None}]),
# Span('pannud', [{'normalized_form': None}]),
# Span('.', [{'normalized_form': None}]),
# Span('Juhan', [{'normalized_form': None}]),
# Span('Lesserberg', [{'normalized_form': None}]),
# Span('sai', [{'normalized_form': None}]),
# Span('ette', [{'normalized_form': None}]),
# Span('kutsutud', [{'normalized_form': None}]),
# Span('ja', [{'normalized_form': None}]),
# Span('tunistas', [{'normalized_form': None}]),
# Span('et', [{'normalized_form': None}]),
# Span('tema', [{'normalized_form': None}]),
# Span('põlla', [{'normalized_form': None}]),
# Span('Juhan', [{'normalized_form': None}]),
# Span('Asse', [{'normalized_form': None}]),
# Span('lükkanud', [{'normalized_form': None}]),
# Span('aga', [{'normalized_form': None}]),
# Span('sõimamest', [{'normalized_form': None}]),
# Span('ja', [{'normalized_form': None}]),
# Span('vandumest', [{'normalized_form': None}]),
# Span('ei', [{'normalized_form': None}]),
# Span('aiand', [{'normalized_form': None}]),
# Span('tema', [{'normalized_form': None}]),
# Span('tagasi', [{'normalized_form': None}]),
# Span('vabandas', [{'normalized_form': None}]),
# Span('ennast', [{'normalized_form': None}]),
# Span('seega', [{'normalized_form': None}]),
# Span('ütteldes', [{'normalized_form': None}]),
# Span('tema', [{'normalized_form': None}]),
# Span('olnud', [{'normalized_form': None}]),
# Span('joobnud', [{'normalized_form': None}]),
# Span('olnud', [{'normalized_form': None}]),
# Span('.', [{'normalized_form': None}]),
# Span('Kohus', [{'normalized_form': None}]),
# Span('mõistis', [{'normalized_form': None}]),
# Span('selle', [{'normalized_form': None}]),
# Span('pärast', [{'normalized_form': None}]),
# Span('et', [{'normalized_form': None}]),
# Span('Juhan', [{'normalized_form': None}]),
# Span('Lesserberg', [{'normalized_form': None}]),
# Span('maksab', [{'normalized_form': None}]),
# Span('4', [{'normalized_form': None}]),
# Span('Rbl', [{'normalized_form': None}]),
# Span('.', [{'normalized_form': None}]),
# Span('trahwi', [{'normalized_form': None}]),
# Span('et', [{'normalized_form': None}]),
# Span('se', [{'normalized_form': None}]),
# Span('riid', [{'normalized_form': None}]),
# Span('neil', [{'normalized_form': None}]),
# Span('kooli', [{'normalized_form': None}]),
# Span('majas', [{'normalized_form': None}]),
# Span('peetava', [{'normalized_form': None}]),
# Span('palwe', [{'normalized_form': None}]),
# Span('tunni', [{'normalized_form': None}]),
# Span('aegus', [{'normalized_form': None}]),
# Span('olnud', [{'normalized_form': None}]),
# Span('ja', [{'normalized_form': None}]),
# Span('ja', [{'normalized_form': None}]),
# Span('sellelabi', [{'normalized_form': None}]),
# Span('rahu', [{'normalized_form': None}]),
# Span('rikumene', [{'normalized_form': None}]),
# Span('sündind', [{'normalized_form': None}]),
# Span('nenda', [{'normalized_form': None}]),
# Span('samma', [{'normalized_form': None}]),
# Span('maksab', [{'normalized_form': None}]),
# Span('Juhan', [{'normalized_form': None}]),
# Span('Asse', [{'normalized_form': None}]),
# Span('1', [{'normalized_form': None}]),
# Span('Rbl', [{'normalized_form': None}]),
# Span('.', [{'normalized_form': None}]),
# Span('trahwi', [{'normalized_form': None}]),
# Span('walla', [{'normalized_form': None}]),
# Span('laeka', [{'normalized_form': None}]),
# Span('selle', [{'normalized_form': None}]),
# Span('riiu', [{'normalized_form': None}]),
# Span('pärast', [{'normalized_form': None}]),
# Span('.', [{'normalized_form': None}])])

# %%
text.tokens
# Out:
# Layer(name='tokens', attributes=(), spans=SL[Span('Astus', [{}]),
# Span('kohtu', [{}]),
# Span('ette', [{}]),
# Span('Koolivöörmünder', [{}]),
# Span('J', [{}]),
# Span('.', [{}]),
# Span('Krais', [{}]),
# Span('ja', [{}]),
# Span('kaebas', [{}]),
# Span('et', [{}]),
# Span('Juhan', [{}]),
# Span('Lesserberg', [{}]),
# Span('ja', [{}]),
# Span('Juhan', [{}]),
# Span('Asse', [{}]),
# Span('olla', [{}]),
# Span('kolimaia', [{}]),
# Span('ükse', [{}]),
# Span('ees', [{}]),
# Span('rielnud', [{}]),
# Span('ja', [{}]),
# Span('peale', [{}]),
# Span('riiu', [{}]),
# Span('lahutust', [{}]),
# Span('olla', [{}]),
# Span('J', [{}]),
# Span('.', [{}]),
# Span('Lesserberg', [{}]),
# Span('hirmsaste', [{}]),
# Span('sõimand', [{}]),
# Span('ja', [{}]),
# Span('vandund', [{}]),
# Span('.', [{}]),
# Span('Juhan', [{}]),
# Span('Asse', [{}]),
# Span('sai', [{}]),
# Span('ette', [{}]),
# Span('kutsutud', [{}]),
# Span('tunistas', [{}]),
# Span('et', [{}]),
# Span('Lesserberg', [{}]),
# Span('olla', [{}]),
# Span('teda', [{}]),
# Span('lükanud', [{}]),
# Span('selle', [{}]),
# Span('peale', [{}]),
# Span('olla', [{}]),
# Span('nemad', [{}]),
# Span('karvupidi', [{}]),
# Span('kokku', [{}]),
# Span('juhtunud', [{}]),
# Span('ja', [{}]),
# Span('teine', [{}]),
# Span('teist', [{}]),
# Span('hilma', [{}]),
# Span('wiga', [{}]),
# Span('tegemata', [{}]),
# Span('maha', [{}]),
# Span('pannud', [{}]),
# Span('.', [{}]),
# Span('Juhan', [{}]),
# Span('Lesserberg', [{}]),
# Span('sai', [{}]),
# Span('ette', [{}]),
# Span('kutsutud', [{}]),
# Span('ja', [{}]),
# Span('tunistas', [{}]),
# Span('et', [{}]),
# Span('tema', [{}]),
# Span('põlla', [{}]),
# Span('Juhan', [{}]),
# Span('Asse', [{}]),
# Span('lükkanud', [{}]),
# Span('aga', [{}]),
# Span('sõimamest', [{}]),
# Span('ja', [{}]),
# Span('vandumest', [{}]),
# Span('ei', [{}]),
# Span('aiand', [{}]),
# Span('tema', [{}]),
# Span('tagasi', [{}]),
# Span('vabandas', [{}]),
# Span('ennast', [{}]),
# Span('seega', [{}]),
# Span('ütteldes', [{}]),
# Span('tema', [{}]),
# Span('olnud', [{}]),
# Span('joobnud', [{}]),
# Span('olnud', [{}]),
# Span('.', [{}]),
# Span('Kohus', [{}]),
# Span('mõistis', [{}]),
# Span('selle', [{}]),
# Span('pärast', [{}]),
# Span('et', [{}]),
# Span('Juhan', [{}]),
# Span('Lesserberg', [{}]),
# Span('maksab', [{}]),
# Span('4', [{}]),
# Span('Rbl', [{}]),
# Span('.', [{}]),
# Span('trahwi', [{}]),
# Span('et', [{}]),
# Span('se', [{}]),
# Span('riid', [{}]),
# Span('neil', [{}]),
# Span('kooli', [{}]),
# Span('majas', [{}]),
# Span('peetava', [{}]),
# Span('palwe', [{}]),
# Span('tunni', [{}]),
# Span('aegus', [{}]),
# Span('olnud', [{}]),
# Span('ja', [{}]),
# Span('ja', [{}]),
# Span('sellelabi', [{}]),
# Span('rahu', [{}]),
# Span('rikumene', [{}]),
# Span('sündind', [{}]),
# Span('nenda', [{}]),
# Span('samma', [{}]),
# Span('maksab', [{}]),
# Span('Juhan', [{}]),
# Span('Asse', [{}]),
# Span('1', [{}]),
# Span('Rbl', [{}]),
# Span('.', [{}]),
# Span('trahwi', [{}]),
# Span('walla', [{}]),
# Span('laeka', [{}]),
# Span('selle', [{}]),
# Span('riiu', [{}]),
# Span('pärast', [{}]),
# Span('.', [{}])])

# %%
# creating a new layer to add to the Text object later on
gold_ner_layer = Layer(name="gold_ner", text_object=text, attributes=['nertag'])
gold_wordner_layer = Layer(name="gold_wordner", text_object=text, attributes=['nertag'])

# %%
# creating a dictionary to hold the annotation data, the dictionary looks as follows:
# {"TRIGGER": ['NERTAG INDEX1 INDEX2', 'NAMED-ENTITY'], ...}
annotation_dictionary = {}

splitted_annotation = annotation.split("\n")
for row in splitted_annotation:
    splitted_row = row.split("\t")
    if (len(splitted_row) == 3):
        trigger = splitted_row[0]
        location = splitted_row[1]
        entity = splitted_row[2]
        annotation_dictionary[trigger] = [location, entity]
    else:
        continue

# %%
# looping through every key and value in dictionary to add to the layer
for key in annotation_dictionary:
    value = annotation_dictionary.get(key)
    ner, loc = value[0].split(" ")[0], (value[0].split(" ")[1], value[0].split(" ")[2])
    preceding_newlines = text.text[0:int(loc[0])].count("\n") #counting preceding newlines to deduct from the indexes (BRAT-problem)
    location1 = int(loc[0]) - int(preceding_newlines)
    location2 = int(loc[1]) - int(preceding_newlines)
    if ner == "Isik":
        gold_ner_layer.add_annotation((location1, location2), nertag="PER")
    if ner == "KO_koht" or ner == "KO_org":
        gold_ner_layer.add_annotation((location1, location2), nertag="LOC")
        gold_ner_layer.add_annotation((location1, location2), nertag="ORG")
    if ner == "Koht":
        gold_ner_layer.add_annotation((location1, location2), nertag="LOC")
    if ner == "Org":
        gold_ner_layer.add_annotation((location1, location2), nertag="ORG")
    if ner == "Muu" or ner == "Teadmata" or ner == "ese":
        gold_ner_layer.add_annotation((location1, location2), nertag="MISC")
text.add_layer(gold_ner_layer)
text.add_layer(gold_wordner_layer)

# %%
splitted_names = []

for value in annotation_dictionary.values():
    print(value[1])
    splitted_name = value[1].split(" ")
    splitted_names.append(splitted_name)
print(splitted_names)
# Out:
# J. Krais
# Juhan Lesserberg
# Juhan Asse
# J.Lesserberg
# Juhan Asse
# Lesserberg
# Juhan Lesserberg
# Juhan Asse
# Juhan Lesserberg
# Juhan Asse
# [['J.', 'Krais'], ['Juhan', 'Lesserberg'], ['Juhan', 'Asse'], ['J.Lesserberg'], ['Juhan', 'Asse'], ['Lesserberg'], ['Juhan', 'Lesserberg'], ['Juhan', 'Asse'], ['Juhan', 'Lesserberg'], ['Juhan', 'Asse']]

# %%
text.gold_ner
# Out:
# Layer(name='gold_ner', attributes=('nertag',), spans=SL[Span('J. Krais', [{'nertag': 'PER'}]),
# Span('Juhan Lesserberg', [{'nertag': 'PER'}]),
# Span('Juhan Asse', [{'nertag': 'PER'}]),
# Span('J.Lesserberg', [{'nertag': 'PER'}]),
# Span('Juhan Asse', [{'nertag': 'PER'}]),
# Span('Lesserberg', [{'nertag': 'PER'}]),
# Span('Juhan Lesserberg', [{'nertag': 'PER'}]),
# Span('Juhan Asse', [{'nertag': 'PER'}]),
# Span('Juhan Lesserberg', [{'nertag': 'PER'}]),
# Span('Juhan Asse', [{'nertag': 'PER'}])])

# %%
text.gold_wordner
# Out:
# Layer(name='gold_wordner', attributes=('nertag',), spans=SL[])
