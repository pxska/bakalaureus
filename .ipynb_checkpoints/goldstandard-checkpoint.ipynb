# %% [raw]
# See praegune gold_ner kihi loomine on, jah, ligilähedaselt sarnane ner kihi loomisega siin -- ainult selle erinevusega, et ner on ümbriskiht ehk siis enveloping layer words kihi ümber, aga gold_ner on Sul lihtkiht, st läheb otse tekstile, ilma teisi kihte puudutamata.
# Tegelikult tuleks gold_ner teha ümbriskihina küll, jah. Nii saame muuhulgas teada, kas / kui hästi EstNLTK automaatsõnestus klapib käsitsimärgenduse sõnapiiridega.
# Kuidas ümbriskihte luua, seda selgitab baastarkuste materjal.
#
# Fraasi-kaupa märgendused ehk kiht gold_ner. Iga käsitsimärgenduse puhul:
# 1) .ann failist saad nimeüksuse indeksid start ja end (need, mida Sa praegu nimetad koodis (location1, location2) );
# 2) leiad kõik words kihi elemendid, mis jäävad nende start ja end indeksite vahele ( words kihi elementide on samuti kõigil start ja end);
# 3) tekitad words kihi elemendite järgi EnvelopingBaseSpan / EnvelopingSpan / Annotation ning lisad need kihile, nagu baastarkustes näidatud;
# Tulemuseks saad gold_ner kihi, mida saab kasutada hindamisel (kui on vaja täpsust fraaside kaupa hinnata -- ehk kui hästi osatakse tuvastada tervikfraase?). Aga treenimisel on vajalik, et märgendused oleks sõna-kaupa.
#
# Sõna-kaupa märgendused ehk gold_wordner kiht. Siin vastab sellele wordner.
# Igal juhul, kui Sul on eelmise kihi punkt 2 täidetud (st leitud words kihi elemendid, mida nimeüksus katab), siis saad sõna märgendused meelde jätta -- panna sõnastikku, kus iga sõna indeksile vastab selle märgend ning esimene element saab märgendi B-... ja kõik järgmised I-... .
# Näiteks, esimene ['Juhan', 'Lesserberg'] nimeüksus katab sõnu 'Juhan' (sõna indeks 8) ja 'Lesserberg' (sõna indeks 9), järelikult saab sõnastikku panna 8 -> 'B-PER' ja 9 -> 'I-PER'.
# Ning kui kõik käsitsimärgendused on nii sõnastikku pandud, tuleb lihtsalt teha tsükkel üle words kihi ja lisada märgend iga sõna kohta.
# Kui sõna pole sõnastikus, saab selle märgendiks 'O', vastasel juhul aga tuleb märgend sõnastikust.
#
# Ok, see asi ka. Siin on wordner kiht words ümbriskihiks tehtud, aga see pole päris korrektne. Lihtsam ja selgem oleks, kui see oleks words kihi alamkiht. Nii et gold_wordner võiks olla words alamkiht. Alamkihtide loomise näited leiad samuti baastarkustest.
#
# Väike märkus: märgenduste sisselugemisel
#
# for row in splitted_annotation:
#     splitted_row = row.split("\t")
#     if (len(splitted_row) == 3):
#         trigger = splitted_row[0]
#         location = splitted_row[1]
#         entity = splitted_row[2]
#         annotation_dictionary[trigger] = [location, entity]
#     else:
#         continue
# Kui ei kehti len(splitted_row) == 3, aga tegemist pole ka tühja reaga, võiks uurida, mis värk seal on.
# Nt esialgu printida, et error, rida ei vasta formaadile vms. Et palju selliseid formaadile mittevastavaid ridu tekib?

# %%
import os
import re

from estnltk import EnvelopingBaseSpan
from estnltk import Text, Layer, Annotation, EnvelopingSpan

# %%
with open("vallakohus_esimene\Harju_Hageri_Kohila_id20604_1883a.ann", encoding="UTF8") as annotated_file:
    annotation = annotated_file.read()
with open("vallakohus_esimene\Harju_Hageri_Kohila_id20604_1883a.txt", encoding="UTF8") as txt:
    textfile = txt.read()

# %%
print(annotation)
# Out:
# T1	Isik 34 42	J. Krais
# T2	Isik 56 72	Juhan Lesserberg
# T3	Isik 76 86	Juhan Asse
# T4	Isik 146 158	J.Lesserberg
# T5	Isik 190 200	Juhan Asse
# T6	Isik 231 241	Lesserberg
# T7	Isik 357 373	Juhan Lesserberg
# T8	Isik 418 428	Juhan Asse
# T9	Isik 584 600	Juhan Lesserberg
# T10	Isik 740 750	Juhan Asse

# %%
# converting the text form .txt file into an EstNLTK Text object
text = Text(textfile)
text = text.tag_layer(['words'])

# %%
# creating a new layer to add to the Text object later on
gold_ner_layer = Layer(name="gold_ner", text_object=text, attributes=['nertag'])
gold_wordner_layer = Layer(name="gold_wordner", text_object=text, attributes=['nertag'])

# %%
# creating a dictionary to hold the annotation data, the dictionary looks as follows:
# {"TRIGGER": ['NERTAG INDEX1 INDEX2', 'NAMED-ENTITY'], ...}
annotation_dictionary = {}

splitted_annotation = annotation.split("\n")
for row in splitted_annotation:
    splitted_row = row.split("\t")
    if (len(splitted_row) == 3):
        trigger = splitted_row[0]
        location = splitted_row[1]
        entity = splitted_row[2]
        annotation_dictionary[trigger] = [location, entity]
    else:
        print("Rea '" + row + "' lugemisel tekkis probleem.")
# Out:
# Rea '' lugemisel tekkis probleem.

# %%
# looping through every key and value in dictionary to add to the layer
for key in annotation_dictionary:    
    value = annotation_dictionary.get(key)
    print(key, value)
# Out:
# T1 ['Isik 34 42', 'J. Krais']
# T2 ['Isik 56 72', 'Juhan Lesserberg']
# T3 ['Isik 76 86', 'Juhan Asse']
# T4 ['Isik 146 158', 'J.Lesserberg']
# T5 ['Isik 190 200', 'Juhan Asse']
# T6 ['Isik 231 241', 'Lesserberg']
# T7 ['Isik 357 373', 'Juhan Lesserberg']
# T8 ['Isik 418 428', 'Juhan Asse']
# T9 ['Isik 584 600', 'Juhan Lesserberg']
# T10 ['Isik 740 750', 'Juhan Asse']

# %%
dictionary_for_wordner = {}
T = 1

for key in annotation_dictionary:
    name = []
    value = annotation_dictionary.get(key)
    ner, loc = value[0].split(" ")[0], (value[0].split(" ")[1], value[0].split(" ")[2])
    preceding_newlines = text.text[0:int(loc[0])].count("\n") #counting preceding newlines to deduct from the indexes
    
    startIndex = int(loc[0]) - int(preceding_newlines)
    endIndex = int(loc[1]) - int(preceding_newlines)
    
    for i in range(0, len(text.words) - 1):
        if text.words[i].start == startIndex:
            if text.words[i].end == endIndex:
                base_span = EnvelopingBaseSpan([text.words[i].base_span])
                name = [text.words[i]]
            else:
                if text.words[i+1].end == endIndex:
                    name = [text.words[i], text.words[i+1]]
                    base_span = EnvelopingBaseSpan([s.base_span for s in name])
                else:
                    for j in range(len(value[0].split(" ") - 1)):
                        name.append(text.words[i+j])
                base_span = EnvelopingBaseSpan([s.base_span for s in name])
                
            new_span = EnvelopingSpan(base_span, layer=gold_ner_layer)
            
            if ner == "Isik":
                new_span.add_annotation(Annotation(new_span, nertag="PER"))
                print(f"ISIK: {new_span} on lisatud.")
                print(name)
                for k in range(0, len(name)):
                    if k == 0:
                        dictionary_for_wordner["B-PER" + " " + str(T)] = i
                        continue
                    else:
                        dictionary_for_wordner["I-PER" + " " + str(T)] = i+k
            if ner == "KO_koht" or ner == "KO_org":
                new_span.add_annotation(Annotation(new_span, nertag="LOC"))
                new_span.add_annotation(Annotation(new_span, nertag="ORG"))
                print(f"LOC_ORG: {new_span} on lisatud.")
                for k in range(0, len(name)):
                    if k == 0:
                        dictionary_for_wordner["B-LOC" + " " + str(T)] = i
                        dictionary_for_wordner["B-ORG" + " " + str(T)] = i
                        continue
                        
                    else:
                        dictionary_for_wordner["I-LOC" + " " + str(T)] = i+k
                        dictionary_for_wordner["I-ORG" + " " + str(T)] = i+k
            if ner == "Koht":
                new_span.add_annotation(Annotation(new_span, nertag="LOC"))
                print(f"LOC: {new_span} on lisatud.")
                for k in range(0, len(name)):
                    if k == 0:
                        dictionary_for_wordner["B-LOC" + " " + str(T)] = i
                        continue
                    else:
                        dictionary_for_wordner["I-LOC" + " " + str(T)] = i+k
            if ner == "Org":
                new_span.add_annotation(Annotation(new_span, nertag="ORG"))
                print(f"ORG: {new_span} on lisatud.")
                for k in range(0, len(name)):
                    if k == 0:
                        dictionary_for_wordner["B-ORG" + " " + str(T)] = i
                        continue
                    else:
                        dictionary_for_wordner["I-ORG" + " " + str(T)] = i+k
            if ner == "Muu" or ner == "Teadmata" or ner == "ese":
                new_span.add_annotation(Annotation(new_span, nertag="MISC"))
                print(f"MISC: {new_span} on lisatud.")
                for k in range(0, len(name)):
                    if k == 0:
                        dictionary_for_wordner["B-MISC" + " " + str(T)] = i
                        continue
                    else:
                        dictionary_for_wordner["I-MISC" + " " + str(T)] = i+k
            gold_ner_layer.add_span(new_span)
            T += 1
            break
text.add_layer(gold_ner_layer)
#text.add_layer(gold_wordner_layer)
# Out:
# ISIK: EnvelopingSpan(['J. Krais'], [{'nertag': 'PER'}]) on lisatud.
# [Span('J. Krais', [{'normalized_form': 'J. Krais'}])]
# ISIK: EnvelopingSpan(['Juhan', 'Lesserberg'], [{'nertag': 'PER'}]) on lisatud.
# [Span('Juhan', [{'normalized_form': None}]), Span('Lesserberg', [{'normalized_form': None}])]
# ISIK: EnvelopingSpan(['Juhan', 'Asse'], [{'nertag': 'PER'}]) on lisatud.
# [Span('Juhan', [{'normalized_form': None}]), Span('Asse', [{'normalized_form': None}])]
# ISIK: EnvelopingSpan(['J.Lesserberg'], [{'nertag': 'PER'}]) on lisatud.
# [Span('J.Lesserberg', [{'normalized_form': 'J.Lesserberg'}])]
# ISIK: EnvelopingSpan(['Juhan', 'Asse'], [{'nertag': 'PER'}]) on lisatud.
# [Span('Juhan', [{'normalized_form': None}]), Span('Asse', [{'normalized_form': None}])]
# ISIK: EnvelopingSpan(['Lesserberg'], [{'nertag': 'PER'}]) on lisatud.
# [Span('Lesserberg', [{'normalized_form': None}])]
# ISIK: EnvelopingSpan(['Juhan', 'Lesserberg'], [{'nertag': 'PER'}]) on lisatud.
# [Span('Juhan', [{'normalized_form': None}]), Span('Lesserberg', [{'normalized_form': None}])]
# ISIK: EnvelopingSpan(['Juhan', 'Asse'], [{'nertag': 'PER'}]) on lisatud.
# [Span('Juhan', [{'normalized_form': None}]), Span('Asse', [{'normalized_form': None}])]
# ISIK: EnvelopingSpan(['Juhan', 'Lesserberg'], [{'nertag': 'PER'}]) on lisatud.
# [Span('Juhan', [{'normalized_form': None}]), Span('Lesserberg', [{'normalized_form': None}])]
# ISIK: EnvelopingSpan(['Juhan', 'Asse'], [{'nertag': 'PER'}]) on lisatud.
# [Span('Juhan', [{'normalized_form': None}]), Span('Asse', [{'normalized_form': None}])]

# %%
for key in dictionary_for_wordner:
    val = dictionary_for_wordner.get(key)
    key_nertag = key.split(" ")[0]
    for i in range(0, len(text.words) - 1):
        try:
            if i == val:
                base_span = EnvelopingBaseSpan([text.words[i].base_span])
                new_span = EnvelopingSpan(base_span, layer=gold_wordner_layer)
                new_span.add_annotation(Annotation(new_span, nertag=str(key_nertag)))
                gold_wordner_layer.add_span(new_span)
                break
            else:
                base_span_o = EnvelopingBaseSpan([text.words[i].base_span])
                new_span_o = EnvelopingSpan(base_span_o, layer=gold_wordner_layer)
                new_span_o.add_annotation(Annotation(new_span_o, nertag="O"))
                gold_wordner_layer.add_span(new_span_o)
        except:
            continue
            
text.add_layer(gold_wordner_layer)

# %%
text.gold_ner
# Out:
# Layer(name='gold_ner', attributes=('nertag',), spans=SL[EnvelopingSpan(['J. Krais'], [{'nertag': 'PER'}]),
# EnvelopingSpan(['Juhan', 'Lesserberg'], [{'nertag': 'PER'}]),
# EnvelopingSpan(['Juhan', 'Asse'], [{'nertag': 'PER'}]),
# EnvelopingSpan(['J.Lesserberg'], [{'nertag': 'PER'}]),
# EnvelopingSpan(['Juhan', 'Asse'], [{'nertag': 'PER'}]),
# EnvelopingSpan(['Lesserberg'], [{'nertag': 'PER'}]),
# EnvelopingSpan(['Juhan', 'Lesserberg'], [{'nertag': 'PER'}]),
# EnvelopingSpan(['Juhan', 'Asse'], [{'nertag': 'PER'}]),
# EnvelopingSpan(['Juhan', 'Lesserberg'], [{'nertag': 'PER'}]),
# EnvelopingSpan(['Juhan', 'Asse'], [{'nertag': 'PER'}])])

# %%
text.gold_wordner
# Out:
# Layer(name='gold_wordner', attributes=('nertag',), spans=SL[EnvelopingSpan(['Astus'], [{'nertag': 'O'}]),
# EnvelopingSpan(['kohtu'], [{'nertag': 'O'}]),
# EnvelopingSpan(['ette'], [{'nertag': 'O'}]),
# EnvelopingSpan(['Koolivöörmünder'], [{'nertag': 'O'}]),
# EnvelopingSpan(['J. Krais'], [{'nertag': 'B-PER'}]),
# EnvelopingSpan(['ja'], [{'nertag': 'O'}]),
# EnvelopingSpan(['kaebas'], [{'nertag': 'O'}]),
# EnvelopingSpan(['et'], [{'nertag': 'O'}]),
# EnvelopingSpan(['Juhan'], [{'nertag': 'B-PER'}]),
# EnvelopingSpan(['Lesserberg'], [{'nertag': 'I-PER'}]),
# EnvelopingSpan(['ja'], [{'nertag': 'O'}]),
# EnvelopingSpan(['Juhan'], [{'nertag': 'B-PER'}]),
# EnvelopingSpan(['Asse'], [{'nertag': 'I-PER'}]),
# EnvelopingSpan(['olla'], [{'nertag': 'O'}]),
# EnvelopingSpan(['kolimaia'], [{'nertag': 'O'}]),
# EnvelopingSpan(['ükse'], [{'nertag': 'O'}]),
# EnvelopingSpan(['ees'], [{'nertag': 'O'}]),
# EnvelopingSpan(['rielnud'], [{'nertag': 'O'}]),
# EnvelopingSpan(['ja'], [{'nertag': 'O'}]),
# EnvelopingSpan(['peale'], [{'nertag': 'O'}]),
# EnvelopingSpan(['riiu'], [{'nertag': 'O'}]),
# EnvelopingSpan(['lahutust'], [{'nertag': 'O'}]),
# EnvelopingSpan(['olla'], [{'nertag': 'O'}]),
# EnvelopingSpan(['J.Lesserberg'], [{'nertag': 'B-PER'}]),
# EnvelopingSpan(['hirmsaste'], [{'nertag': 'O'}]),
# EnvelopingSpan(['sõimand'], [{'nertag': 'O'}]),
# EnvelopingSpan(['ja'], [{'nertag': 'O'}]),
# EnvelopingSpan(['vandund'], [{'nertag': 'O'}]),
# EnvelopingSpan(['.'], [{'nertag': 'O'}]),
# EnvelopingSpan(['Juhan'], [{'nertag': 'B-PER'}]),
# EnvelopingSpan(['Asse'], [{'nertag': 'I-PER'}]),
# EnvelopingSpan(['sai'], [{'nertag': 'O'}]),
# EnvelopingSpan(['ette'], [{'nertag': 'O'}]),
# EnvelopingSpan(['kutsutud'], [{'nertag': 'O'}]),
# EnvelopingSpan(['tunistas'], [{'nertag': 'O'}]),
# EnvelopingSpan(['et'], [{'nertag': 'O'}]),
# EnvelopingSpan(['Lesserberg'], [{'nertag': 'B-PER'}]),
# EnvelopingSpan(['olla'], [{'nertag': 'O'}]),
# EnvelopingSpan(['teda'], [{'nertag': 'O'}]),
# EnvelopingSpan(['lükanud'], [{'nertag': 'O'}]),
# EnvelopingSpan(['selle'], [{'nertag': 'O'}]),
# EnvelopingSpan(['peale'], [{'nertag': 'O'}]),
# EnvelopingSpan(['olla'], [{'nertag': 'O'}]),
# EnvelopingSpan(['nemad'], [{'nertag': 'O'}]),
# EnvelopingSpan(['karvupidi'], [{'nertag': 'O'}]),
# EnvelopingSpan(['kokku'], [{'nertag': 'O'}]),
# EnvelopingSpan(['juhtunud'], [{'nertag': 'O'}]),
# EnvelopingSpan(['ja'], [{'nertag': 'O'}]),
# EnvelopingSpan(['teine'], [{'nertag': 'O'}]),
# EnvelopingSpan(['teist'], [{'nertag': 'O'}]),
# EnvelopingSpan(['hilma'], [{'nertag': 'O'}]),
# EnvelopingSpan(['wiga'], [{'nertag': 'O'}]),
# EnvelopingSpan(['tegemata'], [{'nertag': 'O'}]),
# EnvelopingSpan(['maha'], [{'nertag': 'O'}]),
# EnvelopingSpan(['pannud'], [{'nertag': 'O'}]),
# EnvelopingSpan(['.'], [{'nertag': 'O'}]),
# EnvelopingSpan(['Juhan'], [{'nertag': 'B-PER'}]),
# EnvelopingSpan(['Lesserberg'], [{'nertag': 'I-PER'}]),
# EnvelopingSpan(['sai'], [{'nertag': 'O'}]),
# EnvelopingSpan(['ette'], [{'nertag': 'O'}]),
# EnvelopingSpan(['kutsutud'], [{'nertag': 'O'}]),
# EnvelopingSpan(['ja'], [{'nertag': 'O'}]),
# EnvelopingSpan(['tunistas'], [{'nertag': 'O'}]),
# EnvelopingSpan(['et'], [{'nertag': 'O'}]),
# EnvelopingSpan(['tema'], [{'nertag': 'O'}]),
# EnvelopingSpan(['põlla'], [{'nertag': 'O'}]),
# EnvelopingSpan(['Juhan'], [{'nertag': 'B-PER'}]),
# EnvelopingSpan(['Asse'], [{'nertag': 'I-PER'}]),
# EnvelopingSpan(['lükkanud'], [{'nertag': 'O'}]),
# EnvelopingSpan(['aga'], [{'nertag': 'O'}]),
# EnvelopingSpan(['sõimamest'], [{'nertag': 'O'}]),
# EnvelopingSpan(['ja'], [{'nertag': 'O'}]),
# EnvelopingSpan(['vandumest'], [{'nertag': 'O'}]),
# EnvelopingSpan(['ei'], [{'nertag': 'O'}]),
# EnvelopingSpan(['aiand'], [{'nertag': 'O'}]),
# EnvelopingSpan(['tema'], [{'nertag': 'O'}]),
# EnvelopingSpan(['tagasi'], [{'nertag': 'O'}]),
# EnvelopingSpan(['vabandas'], [{'nertag': 'O'}]),
# EnvelopingSpan(['ennast'], [{'nertag': 'O'}]),
# EnvelopingSpan(['seega'], [{'nertag': 'O'}]),
# EnvelopingSpan(['ütteldes'], [{'nertag': 'O'}]),
# EnvelopingSpan(['tema'], [{'nertag': 'O'}]),
# EnvelopingSpan(['olnud'], [{'nertag': 'O'}]),
# EnvelopingSpan(['joobnud'], [{'nertag': 'O'}]),
# EnvelopingSpan(['olnud'], [{'nertag': 'O'}]),
# EnvelopingSpan(['.'], [{'nertag': 'O'}]),
# EnvelopingSpan(['Kohus'], [{'nertag': 'O'}]),
# EnvelopingSpan(['mõistis'], [{'nertag': 'O'}]),
# EnvelopingSpan(['selle'], [{'nertag': 'O'}]),
# EnvelopingSpan(['pärast'], [{'nertag': 'O'}]),
# EnvelopingSpan(['et'], [{'nertag': 'O'}]),
# EnvelopingSpan(['Juhan'], [{'nertag': 'B-PER'}]),
# EnvelopingSpan(['Lesserberg'], [{'nertag': 'I-PER'}]),
# EnvelopingSpan(['maksab'], [{'nertag': 'O'}]),
# EnvelopingSpan(['4'], [{'nertag': 'O'}]),
# EnvelopingSpan(['Rbl'], [{'nertag': 'O'}]),
# EnvelopingSpan(['.'], [{'nertag': 'O'}]),
# EnvelopingSpan(['trahwi'], [{'nertag': 'O'}]),
# EnvelopingSpan(['et'], [{'nertag': 'O'}]),
# EnvelopingSpan(['se'], [{'nertag': 'O'}]),
# EnvelopingSpan(['riid'], [{'nertag': 'O'}]),
# EnvelopingSpan(['neil'], [{'nertag': 'O'}]),
# EnvelopingSpan(['kooli'], [{'nertag': 'O'}]),
# EnvelopingSpan(['majas'], [{'nertag': 'O'}]),
# EnvelopingSpan(['peetava'], [{'nertag': 'O'}]),
# EnvelopingSpan(['palwe'], [{'nertag': 'O'}]),
# EnvelopingSpan(['tunni'], [{'nertag': 'O'}]),
# EnvelopingSpan(['aegus'], [{'nertag': 'O'}]),
# EnvelopingSpan(['olnud'], [{'nertag': 'O'}]),
# EnvelopingSpan(['ja'], [{'nertag': 'O'}]),
# EnvelopingSpan(['ja'], [{'nertag': 'O'}]),
# EnvelopingSpan(['sellelabi'], [{'nertag': 'O'}]),
# EnvelopingSpan(['rahu'], [{'nertag': 'O'}]),
# EnvelopingSpan(['rikumene'], [{'nertag': 'O'}]),
# EnvelopingSpan(['sündind'], [{'nertag': 'O'}]),
# EnvelopingSpan(['nenda'], [{'nertag': 'O'}]),
# EnvelopingSpan(['samma'], [{'nertag': 'O'}]),
# EnvelopingSpan(['maksab'], [{'nertag': 'O'}]),
# EnvelopingSpan(['Juhan'], [{'nertag': 'B-PER'}]),
# EnvelopingSpan(['Asse'], [{'nertag': 'I-PER'}])])
